# %%
import mysql.connector

mydb = mysql.connector.connect(
      port=3306,
      user="root",          # XAMPP's default user
      password="",          # XAMPP's default password (leave empty)
      use_pure=True,
      database="mydatabase"
)

mycursor = mydb.cursor()
#mycursor.execute("SHOW DATABASES")
mycursor.execute("CREATE TABLE customers (name VARCHAR(255), address VARCHAR(255))")

for x in mycursor:
  print(x)

# %%
import mysql.connector

mydb = mysql.connector.connect(
      port=3306,
      user="root",          # XAMPP's default user
      password="",          # XAMPP's default password (leave empty)
      use_pure=True,
      database="mydatabase"
)

mycursor = mydb.cursor()

#mycursor.execute("SHOW TABLES")

mycursor.execute("ALTER TABLE customers ADD COLUMN id INT AUTO_INCREMENT PRIMARY KEY")
# Out:
# ---------------------------------------------------------------------------
# ProgrammingError                          Traceback (most recent call last)
# Cell In[54], line 15
#      11 mycursor = mydb.cursor()
#      13 #mycursor.execute("SHOW TABLES")
# ---> 15 mycursor.execute("ALTER TABLE customers ADD COLUMN id INT AUTO_INCREMENT PRIMARY KEY")
#
# File c:\Users\SENQ\anaconda3\Lib\site-packages\mysql\connector\cursor.py:418, in MySQLCursor.execute(self, operation, params, map_results)
#     410 self._executed_list = self._stmt_partition["single_stmts"]
#     411 self._executed = (
#     412     self._stmt_partition["single_stmts"].popleft()
#     413     if map_results
#     414     else self._stmt_partition["mappable_stmt"]
#     415 )
#     417 self._handle_result(
# --> 418     self._connection.cmd_query(
#     419         self._stmt_partition["mappable_stmt"],
#     420         read_timeout=self._read_timeout,
#     421         write_timeout=self._write_timeout,
# ...

# %%
mycursor = mydb.cursor()

sql = "INSERT INTO customers (name, address) VALUES (%s, %s)"
val = ("John", "Highway 21")
mycursor.execute(sql, val)

mydb.commit()

print(mycursor.rowcount, "record inserted.")
# Out:
# 1 record inserted.

# %%
sql = "INSERT INTO customers (name, address) VALUES (%s, %s)"
val = [
  ('Peter', 'Lowstreet 4'),
  ('Amy', 'Apple st 652'),
  ('Hannah', 'Mountain 21'),
  ('Michael', 'Valley 345'),
  ('Sandy', 'Ocean blvd 2'),
  ('Betty', 'Green Grass 1'),
  ('Richard', 'Sky st 331'),
  ('Susan', 'One way 98'),
  ('Vicky', 'Yellow Garden 2'),
  ('Ben', 'Park Lane 38'),
  ('William', 'Central st 954'),
  ('Chuck', 'Main Road 989'),
  ('Viola', 'Sideway 1633')
]

mycursor.executemany(sql, val)

mydb.commit()

print(mycursor.rowcount, "was inserted.")
# Out:
# 13 was inserted.

# %%
mycursor = mydb.cursor()

sql = "INSERT INTO customers (name, address) VALUES (%s, %s)"
val = ("Michelle", "Blue Village")
mycursor.execute(sql, val)

mydb.commit()

print("1 record inserted, ID:", mycursor.lastrowid)
# Out:
# 1 record inserted, ID: 30

# %%
mycursor = mydb.cursor()

mycursor.execute("SELECT * FROM customers")

myresult = mycursor.fetchall()

for x in myresult:
  print(x)
# Out:
# ('John', 'Highway 21', 1)
# ('Peter', 'Lowstreet 4', 2)
# ('Amy', 'Apple st 652', 3)
# ('Hannah', 'Mountain 21', 4)
# ('Michael', 'Valley 345', 5)
# ('Sandy', 'Ocean blvd 2', 6)
# ('Betty', 'Green Grass 1', 7)
# ('Richard', 'Sky st 331', 8)
# ('Susan', 'One way 98', 9)
# ('Vicky', 'Yellow Garden 2', 10)
# ('Ben', 'Park Lane 38', 11)
# ('William', 'Central st 954', 12)
# ('Chuck', 'Main Road 989', 13)
# ('Viola', 'Sideway 1633', 14)
# ('Michelle', 'Blue Village', 15)
# ('John', 'Highway 21', 16)
# ('Peter', 'Lowstreet 4', 17)
# ('Amy', 'Apple st 652', 18)
# ('Hannah', 'Mountain 21', 19)
# ('Michael', 'Valley 345', 20)
# ('Sandy', 'Ocean blvd 2', 21)
# ('Betty', 'Green Grass 1', 22)
# ('Richard', 'Sky st 331', 23)
# ('Susan', 'One way 98', 24)
# ('Vicky', 'Yellow Garden 2', 25)
# ('Ben', 'Park Lane 38', 26)
# ('William', 'Central st 954', 27)
# ('Chuck', 'Main Road 989', 28)
# ('Viola', 'Sideway 1633', 29)
# ('Michelle', 'Blue Village', 30)

# %%
mycursor = mydb.cursor()

mycursor.execute("SELECT name, address FROM customers")

myresult = mycursor.fetchall()

for x in myresult:
  print(x)
# Out:
# ('John', 'Highway 21')
# ('Peter', 'Lowstreet 4')
# ('Amy', 'Apple st 652')
# ('Hannah', 'Mountain 21')
# ('Michael', 'Valley 345')
# ('Sandy', 'Ocean blvd 2')
# ('Betty', 'Green Grass 1')
# ('Richard', 'Sky st 331')
# ('Susan', 'One way 98')
# ('Vicky', 'Yellow Garden 2')
# ('Ben', 'Park Lane 38')
# ('William', 'Central st 954')
# ('Chuck', 'Main Road 989')
# ('Viola', 'Sideway 1633')
# ('Michelle', 'Blue Village')
# ('John', 'Highway 21')
# ('Peter', 'Lowstreet 4')
# ('Amy', 'Apple st 652')
# ('Hannah', 'Mountain 21')
# ('Michael', 'Valley 345')
# ('Sandy', 'Ocean blvd 2')
# ('Betty', 'Green Grass 1')
# ('Richard', 'Sky st 331')
# ('Susan', 'One way 98')
# ('Vicky', 'Yellow Garden 2')
# ('Ben', 'Park Lane 38')
# ('William', 'Central st 954')
# ('Chuck', 'Main Road 989')
# ('Viola', 'Sideway 1633')
# ('Michelle', 'Blue Village')

# %%
import mysql.connector

mydb = mysql.connector.connect(
      port=3306,
      user="root",          # XAMPP's default user
      password="",          # XAMPP's default password (leave empty)
      use_pure=True,
      database="mydatabase"
)
mycursor = mydb.cursor()

mycursor.execute("SELECT * FROM customers")

myresult = mycursor.fetchone()

print(myresult)
# Out:
# ('John', 'Highway 21', 1)

# %%
import mysql.connector

mydb = mysql.connector.connect(
      port=3306,
      user="root",          # XAMPP's default user
      password="",          # XAMPP's default password (leave empty)
      use_pure=True,
      database="mydatabase"
)

mycursor = mydb.cursor()

sql = "SELECT * FROM customers WHERE address ='Park Lane 38'"

mycursor.execute(sql)

myresult = mycursor.fetchall()

for x in myresult:
  print(x)
# Out:
# ('Ben', 'Park Lane 38', 11)
# ('Ben', 'Park Lane 38', 26)

# %%
mycursor = mydb.cursor()

sql = "SELECT * FROM customers WHERE address LIKE '%way%'"

mycursor.execute(sql)

myresult = mycursor.fetchall()

for x in myresult:
  print(x)
# Out:
# ('John', 'Highway 21', 1)
# ('Susan', 'One way 98', 9)
# ('Viola', 'Sideway 1633', 14)
# ('John', 'Highway 21', 16)
# ('Susan', 'One way 98', 24)
# ('Viola', 'Sideway 1633', 29)

# %%
import mysql.connector

mydb = mysql.connector.connect(
      port=3306,
      user="root",          # XAMPP's default user
      password="",          # XAMPP's default password (leave empty)
      use_pure=True,
      database="mydatabase"
)

mycursor = mydb.cursor()

sql = "SELECT * FROM customers WHERE address = %s"
adr = ("Sideway 1633", )

mycursor.execute(sql, adr)

myresult = mycursor.fetchall()

for x in myresult:
  print(x)
# Out:
# ('Viola', 'Sideway 1633', 14)
# ('Viola', 'Sideway 1633', 29)

# %%
import mysql.connector

mydb = mysql.connector.connect(
      port=3306,
      user="root",          # XAMPP's default user
      password="",          # XAMPP's default password (leave empty)
      use_pure=True,
      database="mydatabase"
)

mycursor = mydb.cursor()

sql = "SELECT * FROM customers ORDER BY name"

mycursor.execute(sql)

myresult = mycursor.fetchall()

for x in myresult:
  print(x)
# Out:
# ('Amy', 'Apple st 652', 3)
# ('Amy', 'Apple st 652', 18)
# ('Ben', 'Park Lane 38', 11)
# ('Ben', 'Park Lane 38', 26)
# ('Betty', 'Green Grass 1', 7)
# ('Betty', 'Green Grass 1', 22)
# ('Chuck', 'Main Road 989', 13)
# ('Chuck', 'Main Road 989', 28)
# ('Hannah', 'Mountain 21', 4)
# ('Hannah', 'Mountain 21', 19)
# ('John', 'Highway 21', 1)
# ('John', 'Highway 21', 16)
# ('Michael', 'Valley 345', 5)
# ('Michael', 'Valley 345', 20)
# ('Michelle', 'Blue Village', 15)
# ('Michelle', 'Blue Village', 30)
# ('Peter', 'Lowstreet 4', 2)
# ('Peter', 'Lowstreet 4', 17)
# ('Richard', 'Sky st 331', 8)
# ('Richard', 'Sky st 331', 23)
# ('Sandy', 'Ocean blvd 2', 6)
# ('Sandy', 'Ocean blvd 2', 21)
# ('Susan', 'One way 98', 9)
# ('Susan', 'One way 98', 24)
# ('Vicky', 'Yellow Garden 2', 10)
# ('Vicky', 'Yellow Garden 2', 25)
# ('Viola', 'Sideway 1633', 14)
# ('Viola', 'Sideway 1633', 29)
# ('William', 'Central st 954', 12)
# ('William', 'Central st 954', 27)

# %%
mycursor = mydb.cursor()

sql = "DELETE FROM customers WHERE address = 'Mountain 21'"

mycursor.execute(sql)

mydb.commit()

print(mycursor.rowcount, "record(s) deleted")
# Out:
# 2 record(s) deleted

# %%
mycursor = mydb.cursor()

sql = "DELETE FROM customers WHERE address = %s"
adr = ("Yellow Garden 2", )

mycursor.execute(sql, adr)

mydb.commit()

print(mycursor.rowcount, "record(s) deleted")
# Out:
# 2 record(s) deleted

# %%
import mysql.connector

mydb = mysql.connector.connect(
      port=3306,
      user="root",          # XAMPP's default user
      password="",          # XAMPP's default password (leave empty)
      use_pure=True,
      database="mydatabase"
)
mycursor = mydb.cursor()

sql = "DROP TABLE IF EXISTS customers"

mycursor.execute(sql)

# %%
mycursor = mydb.cursor()

sql = "UPDATE customers SET address = 'Canyon 123' WHERE address = 'Valley 345'"

mycursor.execute(sql)

mydb.commit()


print(mycursor.rowcount, "record(s) affected")
# Out:
# 1 record(s) affected

# %%
mycursor = mydb.cursor()

sql = "UPDATE customers SET address = %s WHERE address = %s"
val = ("Valley 345", "Canyon 123")

mycursor.execute(sql, val)

mydb.commit()

print(mycursor.rowcount, "record(s) affected")
# Out:
# 1 record(s) affected

# %%
mycursor = mydb.cursor()

mycursor.execute("SELECT * FROM customers LIMIT 5")

myresult = mycursor.fetchall()

for x in myresult:
  print(x)
# Out:
# ('Peter', 'Lowstreet 4')
# ('Amy', 'Apple st 652')
# ('Hannah', 'Mountain 21')
# ('Michael', 'Valley 345')
# ('Sandy', 'Ocean blvd 2')

# %%
mycursor = mydb.cursor()

mycursor.execute("SELECT * FROM customers LIMIT 5 OFFSET 2")

myresult = mycursor.fetchall()

for x in myresult:
  print(x)
# Out:
# ('Hannah', 'Mountain 21')
# ('Michael', 'Valley 345')
# ('Sandy', 'Ocean blvd 2')
# ('Betty', 'Green Grass 1')
# ('Richard', 'Sky st 331')

# %%
import mysql.connector

mydb = mysql.connector.connect(
      port=3306,
      user="root",          # XAMPP's default user
      password="",          # XAMPP's default password (leave empty)
      use_pure=True,
      database="mydatabase"
)

# %%
sql = "SELECT \
  users.name AS user, \
  products.name AS favorite \
  FROM users \
  INNER JOIN products ON users.fav = products.id"

mycursor.execute(sql)

myresult = mycursor.fetchall()

for x in myresult:
  print(x)
# Out:
# ---------------------------------------------------------------------------
# ProgrammingError                          Traceback (most recent call last)
# Cell In[9], line 7
#       1 sql = "SELECT \
#       2   users.name AS user, \
#       3   products.name AS favorite \
#       4   FROM users \
#       5   INNER JOIN products ON users.fav = products.id"
# ----> 7 mycursor.execute(sql)
#       9 myresult = mycursor.fetchall()
#      11 for x in myresult:
#
# File c:\Users\SENQ\anaconda3\Lib\site-packages\mysql\connector\cursor.py:418, in MySQLCursor.execute(self, operation, params, map_results)
#     410 self._executed_list = self._stmt_partition["single_stmts"]
#     411 self._executed = (
#     412     self._stmt_partition["single_stmts"].popleft()
#     413     if map_results
#     414     else self._stmt_partition["mappable_stmt"]
#     415 )
#     417 self._handle_result(
# --> 418     self._connection.cmd_query(
#     419         self._stmt_partition["mappable_stmt"],
# ...
