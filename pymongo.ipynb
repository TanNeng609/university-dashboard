# %%
import sys
# !{sys.executable} -m pip install pymongo
# Out:
# Requirement already satisfied: pymongo in c:\users\senq\anaconda3\lib\site-packages (4.16.0)
# Requirement already satisfied: dnspython<3.0.0,>=2.6.1 in c:\users\senq\anaconda3\lib\site-packages (from pymongo) (2.8.0)

# %%
import pymongo
myclient = pymongo.MongoClient("mongodb://localhost:27017/")
mydb = myclient["mydatabase"]
dblist = myclient.list_database_names()
if "mydatabase" in dblist:
  print("The database exists.")
# Out:
# ---------------------------------------------------------------------------
# ServerSelectionTimeoutError               Traceback (most recent call last)
# Cell In[2], line 4
#       2 myclient = pymongo.MongoClient("mongodb://localhost:27017/")
#       3 mydb = myclient["mydatabase"]
# ----> 4 dblist = myclient.list_database_names()
#       5 if "mydatabase" in dblist:
#       6   print("The database exists.")
#
# File c:\Users\SENQ\anaconda3\Lib\site-packages\pymongo\synchronous\mongo_client.py:2385, in MongoClient.list_database_names(self, session, comment)
#    2368 def list_database_names(
#    2369     self,
#    2370     session: Optional[client_session.ClientSession] = None,
#    2371     comment: Optional[Any] = None,
#    2372 ) -> list[str]:
#    2373     """Get a list of the names of all databases on the connected server.
#    2374
#    2375     :param session: a
#    (...)
#    2383     .. versionadded:: 3.6
#    2384     """
# -> 2385     res = self._list_databases(session, nameOnly=True, comment=comment)
#    2386     return [doc["name"] for doc in res]
#
# File c:\Users\SENQ\anaconda3\Lib\site-packages\pymongo\synchronous\mongo_client.py:2325, in MongoClient._list_databases(self, session, comment, **kwargs)
#    2323     cmd["comment"] = comment
#    2324 admin = self._database_default_options("admin")
# -> 2325 res = admin._retryable_read_command(cmd, session=session, operation=_Op.LIST_DATABASES)
#    2326 # listDatabases doesn't return a cursor (yet). Fake one.
#    2327 cursor = {
#    2328     "id": 0,
#    2329     "firstBatch": res["databases"],
#    2330     "ns": "admin.$cmd",
#    2331 }
#
# File c:\Users\SENQ\anaconda3\Lib\site-packages\pymongo\synchronous\database.py:1074, in Database._retryable_read_command(self, command, operation, session)
#    1061 def _cmd(
#    1062     session: Optional[ClientSession],
#    1063     _server: Server,
#    1064     conn: Connection,
#    1065     read_preference: _ServerMode,
#    1066 ) -> dict[str, Any]:
#    1067     return self._command(
#    1068         conn,
#    1069         command,
#    1070         read_preference=read_preference,
#    1071         session=session,
#    1072     )
# -> 1074 return self._client._retryable_read(_cmd, read_preference, session, operation)
#
# File c:\Users\SENQ\anaconda3\Lib\site-packages\pymongo\synchronous\mongo_client.py:2048, in MongoClient._retryable_read(self, func, read_pref, session, operation, address, retryable, operation_id)
#    2044 retryable = bool(
#    2045     retryable and self.options.retry_reads and not (session and session.in_transaction)
#    2046 )
#    2047 with self._tmp_session(session) as s:
# -> 2048     return self._retry_internal(
#    2049         func,
#    2050         s,
#    2051         None,
#    2052         operation,
#    2053         is_read=True,
#    2054         address=address,
#    2055         read_pref=read_pref,
#    2056         retryable=retryable,
#    2057         operation_id=operation_id,
#    2058     )
#
# File c:\Users\SENQ\anaconda3\Lib\site-packages\pymongo\_csot.py:125, in apply.<locals>.csot_wrapper(self, *args, **kwargs)
#     123         with _TimeoutContext(timeout):
#     124             return func(self, *args, **kwargs)
# --> 125 return func(self, *args, **kwargs)
#
# File c:\Users\SENQ\anaconda3\Lib\site-packages\pymongo\synchronous\mongo_client.py:2014, in MongoClient._retry_internal(self, func, session, bulk, operation, is_read, address, read_pref, retryable, operation_id)
#    1977 @_csot.apply
#    1978 def _retry_internal(
#    1979     self,
#    (...)
#    1988     operation_id: Optional[int] = None,
#    1989 ) -> T:
#    1990     """Internal retryable helper for all client transactions.
#    1991
#    1992     :param func: Callback function we want to retry
#    (...)
#    2001     :return: Output of the calling func()
#    2002     """
#    2003     return _ClientConnectionRetryable(
#    2004         mongo_client=self,
#    2005         func=func,
#    2006         bulk=bulk,
#    2007         operation=operation,
#    2008         is_read=is_read,
#    2009         session=session,
#    2010         read_pref=read_pref,
#    2011         address=address,
#    2012         retryable=retryable,
#    2013         operation_id=operation_id,
# -> 2014     ).run()
#
# File c:\Users\SENQ\anaconda3\Lib\site-packages\pymongo\synchronous\mongo_client.py:2763, in _ClientConnectionRetryable.run(self)
#    2761 self._check_last_error(check_csot=True)
#    2762 try:
# -> 2763     return self._read() if self._is_read else self._write()
#    2764 except ServerSelectionTimeoutError:
#    2765     # The application may think the write was never attempted
#    2766     # if we raise ServerSelectionTimeoutError on the retry
#    2767     # attempt. Raise the original exception instead.
#    2768     self._check_last_error()
#
# File c:\Users\SENQ\anaconda3\Lib\site-packages\pymongo\synchronous\mongo_client.py:2908, in _ClientConnectionRetryable._read(self)
#    2903 def _read(self) -> T:
#    2904     """Wrapper method for read-type retryable client executions
#    2905
#    2906     :return: Output for func()'s call
#    2907     """
# -> 2908     self._server = self._get_server()
#    2909     assert self._read_pref is not None, "Read Preference required on read calls"
#    2910     with self._client._conn_from_server(self._read_pref, self._server, self._session) as (
#    2911         conn,
#    2912         read_pref,
#    2913     ):
#
# File c:\Users\SENQ\anaconda3\Lib\site-packages\pymongo\synchronous\mongo_client.py:2856, in _ClientConnectionRetryable._get_server(self)
#    2851 def _get_server(self) -> Server:
#    2852     """Retrieves a server object based on provided object context
#    2853
#    2854     :return: Abstraction to connect to server
#    2855     """
# -> 2856     return self._client._select_server(
#    2857         self._server_selector,
#    2858         self._session,
#    2859         self._operation,
#    2860         address=self._address,
#    2861         deprioritized_servers=self._deprioritized_servers,
#    2862         operation_id=self._operation_id,
#    2863     )
#
# File c:\Users\SENQ\anaconda3\Lib\site-packages\pymongo\synchronous\mongo_client.py:1833, in MongoClient._select_server(self, server_selector, session, operation, address, deprioritized_servers, operation_id)
#    1831             raise AutoReconnect("server %s:%s no longer available" % address)  # noqa: UP031
#    1832     else:
# -> 1833         server = topology.select_server(
#    1834             server_selector,
#    1835             operation,
#    1836             deprioritized_servers=deprioritized_servers,
#    1837             operation_id=operation_id,
#    1838         )
#    1839     return server
#    1840 except PyMongoError as exc:
#    1841     # Server selection errors in a transaction are transient.
#
# File c:\Users\SENQ\anaconda3\Lib\site-packages\pymongo\synchronous\topology.py:428, in Topology.select_server(self, selector, operation, server_selection_timeout, address, deprioritized_servers, operation_id)
#     418 def select_server(
#     419     self,
#     420     selector: Callable[[Selection], Selection],
#    (...)
#     425     operation_id: Optional[int] = None,
#     426 ) -> Server:
#     427     """Like select_servers, but choose a random server if several match."""
# --> 428     server = self._select_server(
#     429         selector,
#     430         operation,
#     431         server_selection_timeout,
#     432         address,
#     433         deprioritized_servers,
#     434         operation_id=operation_id,
#     435     )
#     436     if _csot.get_timeout():
#     437         _csot.set_rtt(server.description.min_round_trip_time)
#
# File c:\Users\SENQ\anaconda3\Lib\site-packages\pymongo\synchronous\topology.py:402, in Topology._select_server(self, selector, operation, server_selection_timeout, address, deprioritized_servers, operation_id)
#     393 def _select_server(
#     394     self,
#     395     selector: Callable[[Selection], Selection],
#    (...)
#     400     operation_id: Optional[int] = None,
#     401 ) -> Server:
# --> 402     servers = self.select_servers(
#     403         selector,
#     404         operation,
#     405         server_selection_timeout,
#     406         address,
#     407         operation_id,
#     408         deprioritized_servers,
#     409     )
#     410     if len(servers) == 1:
#     411         return servers[0]
#
# File c:\Users\SENQ\anaconda3\Lib\site-packages\pymongo\synchronous\topology.py:298, in Topology.select_servers(self, selector, operation, server_selection_timeout, address, operation_id, deprioritized_servers)
#     295     self.cleanup_monitors()
#     297 with self._lock:
# --> 298     server_descriptions = self._select_servers_loop(
#     299         selector,
#     300         server_timeout,
#     301         operation,
#     302         operation_id,
#     303         address,
#     304         deprioritized_servers=deprioritized_servers,
#     305     )
#     307     return [
#     308         cast(Server, self.get_server_by_address(sd.address)) for sd in server_descriptions
#     309     ]
#
# File c:\Users\SENQ\anaconda3\Lib\site-packages\pymongo\synchronous\topology.py:359, in Topology._select_servers_loop(self, selector, timeout, operation, operation_id, address, deprioritized_servers)
#     348     if _SERVER_SELECTION_LOGGER.isEnabledFor(logging.DEBUG):
#     349         _debug_log(
#     350             _SERVER_SELECTION_LOGGER,
#     351             message=_ServerSelectionStatusMessage.FAILED,
#    (...)
#     357             failure=self._error_message(selector),
#     358         )
# --> 359     raise ServerSelectionTimeoutError(
#     360         f"{self._error_message(selector)}, Timeout: {timeout}s, Topology Description: {self.description!r}"
#     361     )
#     363 if not logged_waiting:
#     364     _debug_log(
#     365         _SERVER_SELECTION_LOGGER,
#     366         message=_ServerSelectionStatusMessage.WAITING,
#    (...)
#     372         remainingTimeMS=int(1000 * (end_time - time.monotonic())),
#     373     )
#
# ServerSelectionTimeoutError: localhost:27017: [WinError 10061] No connection could be made because the target machine actively refused it (configured timeouts: socketTimeoutMS: 20000.0ms, connectTimeoutMS: 20000.0ms), Timeout: 30s, Topology Description: <TopologyDescription id: 69a3fa971c1bfe19ecde17cd, topology_type: Unknown, servers: [<ServerDescription ('localhost', 27017) server_type: Unknown, rtt: None, error=AutoReconnect('localhost:27017: [WinError 10061] No connection could be made because the target machine actively refused it (configured timeouts: socketTimeoutMS: 20000.0ms, connectTimeoutMS: 20000.0ms)')>]>

# %%
import pymongo

myclient = pymongo.MongoClient("mongodb://localhost:27017/")
mydb = myclient["mydatabase"]

mycol = mydb["customers"]
mydict = { "name": "John", "address": "Highway 37" }

x = mycol.insert_one(mydict)
print(x.inserted_id)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[8], line 9
#       6 mycol = mydb["customers"]
#       7 mydict = { "name": "John", "address": "Highway 37" }
# ----> 9 x = mycol.insert_one(mydict)
#      10 print(x.inserted_id)
#
# File c:\Users\SENQ\anaconda3\Lib\site-packages\pymongo\synchronous\collection.py:891, in Collection.insert_one(self, document, bypass_document_validation, session, comment)
#     887     document["_id"] = ObjectId()  # type: ignore[index]
#     889 write_concern = self._write_concern_for(session)
#     890 return InsertOneResult(
# --> 891     self._insert_one(
#     892         document,
#     893         ordered=True,
#     894         write_concern=write_concern,
#     895         op_id=None,
#     896         bypass_doc_val=bypass_document_validation,
#     897         session=session,
#     898         comment=comment,
#     899     ),
#     900     write_concern.acknowledged,
#     901 )
#
# File c:\Users\SENQ\anaconda3\Lib\site-packages\pymongo\synchronous\collection.py:831, in Collection._insert_one(self, doc, ordered, write_concern, op_id, bypass_doc_val, session, comment)
#     819     result = conn.command(
#     820         self._database.name,
#     821         command,
#    (...)
#     826         retryable_write=retryable_write,
#     827     )
#     829     _check_write_command_response(result)
# --> 831 self._database.client._retryable_write(
#     832     acknowledged, _insert_command, session, operation=_Op.INSERT
#     833 )
#     835 if not isinstance(doc, RawBSONDocument):
#     836     return doc.get("_id")
#
# File c:\Users\SENQ\anaconda3\Lib\site-packages\pymongo\synchronous\mongo_client.py:2083, in MongoClient._retryable_write(self, retryable, func, session, operation, bulk, operation_id)
#    2069 """Execute an operation with consecutive retries if possible
#    2070
#    2071 Returns func()'s return value on success. On error retries the same
#    (...)
#    2080 :param bulk: bulk abstraction to execute operations in bulk, defaults to None
#    2081 """
#    2082 with self._tmp_session(session) as s:
# -> 2083     return self._retry_with_session(retryable, func, s, bulk, operation, operation_id)
#
# File c:\Users\SENQ\anaconda3\Lib\site-packages\pymongo\synchronous\mongo_client.py:1968, in MongoClient._retry_with_session(self, retryable, func, session, bulk, operation, operation_id)
#    1963 # Ensure that the options supports retry_writes and there is a valid session not in
#    1964 # transaction, otherwise, we will not support retry behavior for this txn.
#    1965 retryable = bool(
#    1966     retryable and self.options.retry_writes and session and not session.in_transaction
#    1967 )
# -> 1968 return self._retry_internal(
#    1969     func=func,
#    1970     session=session,
#    1971     bulk=bulk,
#    1972     operation=operation,
#    1973     retryable=retryable,
#    1974     operation_id=operation_id,
#    1975 )
#
# File c:\Users\SENQ\anaconda3\Lib\site-packages\pymongo\_csot.py:125, in apply.<locals>.csot_wrapper(self, *args, **kwargs)
#     123         with _TimeoutContext(timeout):
#     124             return func(self, *args, **kwargs)
# --> 125 return func(self, *args, **kwargs)
#
# File c:\Users\SENQ\anaconda3\Lib\site-packages\pymongo\synchronous\mongo_client.py:2014, in MongoClient._retry_internal(self, func, session, bulk, operation, is_read, address, read_pref, retryable, operation_id)
#    1977 @_csot.apply
#    1978 def _retry_internal(
#    1979     self,
#    (...)
#    1988     operation_id: Optional[int] = None,
#    1989 ) -> T:
#    1990     """Internal retryable helper for all client transactions.
#    1991
#    1992     :param func: Callback function we want to retry
#    (...)
#    2001     :return: Output of the calling func()
#    2002     """
#    2003     return _ClientConnectionRetryable(
#    2004         mongo_client=self,
#    2005         func=func,
#    2006         bulk=bulk,
#    2007         operation=operation,
#    2008         is_read=is_read,
#    2009         session=session,
#    2010         read_pref=read_pref,
#    2011         address=address,
#    2012         retryable=retryable,
#    2013         operation_id=operation_id,
# -> 2014     ).run()
#
# File c:\Users\SENQ\anaconda3\Lib\site-packages\pymongo\synchronous\mongo_client.py:2763, in _ClientConnectionRetryable.run(self)
#    2761 self._check_last_error(check_csot=True)
#    2762 try:
# -> 2763     return self._read() if self._is_read else self._write()
#    2764 except ServerSelectionTimeoutError:
#    2765     # The application may think the write was never attempted
#    2766     # if we raise ServerSelectionTimeoutError on the retry
#    2767     # attempt. Raise the original exception instead.
#    2768     self._check_last_error()
#
# File c:\Users\SENQ\anaconda3\Lib\site-packages\pymongo\synchronous\mongo_client.py:2873, in _ClientConnectionRetryable._write(self)
#    2871 max_wire_version = 0
#    2872 is_mongos = False
# -> 2873 self._server = self._get_server()
#    2874 with self._client._checkout(self._server, self._session) as conn:
#    2875     max_wire_version = conn.max_wire_version
#
# File c:\Users\SENQ\anaconda3\Lib\site-packages\pymongo\synchronous\mongo_client.py:2856, in _ClientConnectionRetryable._get_server(self)
#    2851 def _get_server(self) -> Server:
#    2852     """Retrieves a server object based on provided object context
#    2853
#    2854     :return: Abstraction to connect to server
#    2855     """
# -> 2856     return self._client._select_server(
#    2857         self._server_selector,
#    2858         self._session,
#    2859         self._operation,
#    2860         address=self._address,
#    2861         deprioritized_servers=self._deprioritized_servers,
#    2862         operation_id=self._operation_id,
#    2863     )
#
# File c:\Users\SENQ\anaconda3\Lib\site-packages\pymongo\synchronous\mongo_client.py:1833, in MongoClient._select_server(self, server_selector, session, operation, address, deprioritized_servers, operation_id)
#    1831             raise AutoReconnect("server %s:%s no longer available" % address)  # noqa: UP031
#    1832     else:
# -> 1833         server = topology.select_server(
#    1834             server_selector,
#    1835             operation,
#    1836             deprioritized_servers=deprioritized_servers,
#    1837             operation_id=operation_id,
#    1838         )
#    1839     return server
#    1840 except PyMongoError as exc:
#    1841     # Server selection errors in a transaction are transient.
#
# File c:\Users\SENQ\anaconda3\Lib\site-packages\pymongo\synchronous\topology.py:428, in Topology.select_server(self, selector, operation, server_selection_timeout, address, deprioritized_servers, operation_id)
#     418 def select_server(
#     419     self,
#     420     selector: Callable[[Selection], Selection],
#    (...)
#     425     operation_id: Optional[int] = None,
#     426 ) -> Server:
#     427     """Like select_servers, but choose a random server if several match."""
# --> 428     server = self._select_server(
#     429         selector,
#     430         operation,
#     431         server_selection_timeout,
#     432         address,
#     433         deprioritized_servers,
#     434         operation_id=operation_id,
#     435     )
#     436     if _csot.get_timeout():
#     437         _csot.set_rtt(server.description.min_round_trip_time)
#
# File c:\Users\SENQ\anaconda3\Lib\site-packages\pymongo\synchronous\topology.py:402, in Topology._select_server(self, selector, operation, server_selection_timeout, address, deprioritized_servers, operation_id)
#     393 def _select_server(
#     394     self,
#     395     selector: Callable[[Selection], Selection],
#    (...)
#     400     operation_id: Optional[int] = None,
#     401 ) -> Server:
# --> 402     servers = self.select_servers(
#     403         selector,
#     404         operation,
#     405         server_selection_timeout,
#     406         address,
#     407         operation_id,
#     408         deprioritized_servers,
#     409     )
#     410     if len(servers) == 1:
#     411         return servers[0]
#
# File c:\Users\SENQ\anaconda3\Lib\site-packages\pymongo\synchronous\topology.py:298, in Topology.select_servers(self, selector, operation, server_selection_timeout, address, operation_id, deprioritized_servers)
#     295     self.cleanup_monitors()
#     297 with self._lock:
# --> 298     server_descriptions = self._select_servers_loop(
#     299         selector,
#     300         server_timeout,
#     301         operation,
#     302         operation_id,
#     303         address,
#     304         deprioritized_servers=deprioritized_servers,
#     305     )
#     307     return [
#     308         cast(Server, self.get_server_by_address(sd.address)) for sd in server_descriptions
#     309     ]
#
# File c:\Users\SENQ\anaconda3\Lib\site-packages\pymongo\synchronous\topology.py:383, in Topology._select_servers_loop(self, selector, timeout, operation, operation_id, address, deprioritized_servers)
#     377 self._request_check_all()
#     379 # Release the lock and wait for the topology description to
#     380 # change, or for a timeout. We won't miss any changes that
#     381 # came after our most recent apply_selector call, since we've
#     382 # held the lock until now.
# --> 383 _cond_wait(self._condition, common.MIN_HEARTBEAT_INTERVAL)
#     384 self._description.check_compatible()
#     385 now = time.monotonic()
#
# File c:\Users\SENQ\anaconda3\Lib\site-packages\pymongo\lock.py:92, in _cond_wait(condition, timeout)
#      91 def _cond_wait(condition: threading.Condition, timeout: Optional[float]) -> bool:
# ---> 92     return condition.wait(timeout)
#
# File c:\Users\SENQ\anaconda3\Lib\threading.py:359, in Condition.wait(self, timeout)
#     357 else:
#     358     if timeout > 0:
# --> 359         gotit = waiter.acquire(True, timeout)
#     360     else:
#     361         gotit = waiter.acquire(False)
#
# KeyboardInterrupt:

# %%
import pymongo

myclient = pymongo.MongoClient("mongodb://localhost:27017/")
mydb = myclient["mydatabase"]
mycol = mydb["customers"]

mylist = [
  { "name": "Amy", "address": "Apple st 652"},
  { "name": "Hannah", "address": "Mountain 21"},
  { "name": "Michael", "address": "Valley 345"},
  { "name": "Sandy", "address": "Ocean blvd 2"},
  { "name": "Betty", "address": "Green Grass 1"},
  { "name": "Richard", "address": "Sky st 331"},
  { "name": "Susan", "address": "One way 98"},
  { "name": "Vicky", "address": "Yellow Garden 2"},
  { "name": "Ben", "address": "Park Lane 38"},
  { "name": "William", "address": "Central st 954"},
  { "name": "Chuck", "address": "Main Road 989"},
  { "name": "Viola", "address": "Sideway 1633"}
]

x = mycol.insert_many(mylist)

#print list of the _id values of the inserted documents:
print(x.inserted_ids)
# Out:
# ---------------------------------------------------------------------------
# ServerSelectionTimeoutError               Traceback (most recent call last)
# Cell In[1], line 22
#       5 mycol = mydb["customers"]
#       7 mylist = [
#       8   { "name": "Amy", "address": "Apple st 652"},
#       9   { "name": "Hannah", "address": "Mountain 21"},
#    (...)
#      19   { "name": "Viola", "address": "Sideway 1633"}
#      20 ]
# ---> 22 x = mycol.insert_many(mylist)
#      24 #print list of the _id values of the inserted documents:
#      25 print(x.inserted_ids)
#
# File c:\Users\SENQ\anaconda3\Lib\site-packages\pymongo\_csot.py:125, in apply.<locals>.csot_wrapper(self, *args, **kwargs)
#     123         with _TimeoutContext(timeout):
#     124             return func(self, *args, **kwargs)
# --> 125 return func(self, *args, **kwargs)
#
# File c:\Users\SENQ\anaconda3\Lib\site-packages\pymongo\synchronous\collection.py:975, in Collection.insert_many(self, documents, ordered, bypass_document_validation, session, comment)
#     973 blk = _Bulk(self, ordered, bypass_document_validation, comment=comment)
#     974 blk.ops = list(gen())
# --> 975 blk.execute(write_concern, session, _Op.INSERT)
#     976 return InsertManyResult(inserted_ids, write_concern.acknowledged)
#
# File c:\Users\SENQ\anaconda3\Lib\site-packages\pymongo\synchronous\bulk.py:751, in _Bulk.execute(self, write_concern, session, operation)
#     749         return None
#     750 else:
# --> 751     return self.execute_command(generator, write_concern, session, operation)
#
# File c:\Users\SENQ\anaconda3\Lib\site-packages\pymongo\synchronous\bulk.py:604, in _Bulk.execute_command(self, generator, write_concern, session, operation)
#     593     self._execute_command(
#     594         generator,
#     595         write_concern,
#    (...)
#     600         full_result,
#     601     )
#     603 client = self.collection.database.client
# --> 604 _ = client._retryable_write(
#     605     self.is_retryable,
#     606     retryable_bulk,
#     607     session,
#     608     operation,
#     609     bulk=self,  # type: ignore[arg-type]
#     610     operation_id=op_id,
#     611 )
#     613 if full_result["writeErrors"] or full_result["writeConcernErrors"]:
#     614     _raise_bulk_write_error(full_result)
#
# File c:\Users\SENQ\anaconda3\Lib\site-packages\pymongo\synchronous\mongo_client.py:2083, in MongoClient._retryable_write(self, retryable, func, session, operation, bulk, operation_id)
#    2069 """Execute an operation with consecutive retries if possible
#    2070
#    2071 Returns func()'s return value on success. On error retries the same
#    (...)
#    2080 :param bulk: bulk abstraction to execute operations in bulk, defaults to None
#    2081 """
#    2082 with self._tmp_session(session) as s:
# -> 2083     return self._retry_with_session(retryable, func, s, bulk, operation, operation_id)
#
# File c:\Users\SENQ\anaconda3\Lib\site-packages\pymongo\synchronous\mongo_client.py:1968, in MongoClient._retry_with_session(self, retryable, func, session, bulk, operation, operation_id)
#    1963 # Ensure that the options supports retry_writes and there is a valid session not in
#    1964 # transaction, otherwise, we will not support retry behavior for this txn.
#    1965 retryable = bool(
#    1966     retryable and self.options.retry_writes and session and not session.in_transaction
#    1967 )
# -> 1968 return self._retry_internal(
#    1969     func=func,
#    1970     session=session,
#    1971     bulk=bulk,
#    1972     operation=operation,
#    1973     retryable=retryable,
#    1974     operation_id=operation_id,
#    1975 )
#
# File c:\Users\SENQ\anaconda3\Lib\site-packages\pymongo\_csot.py:125, in apply.<locals>.csot_wrapper(self, *args, **kwargs)
#     123         with _TimeoutContext(timeout):
#     124             return func(self, *args, **kwargs)
# --> 125 return func(self, *args, **kwargs)
#
# File c:\Users\SENQ\anaconda3\Lib\site-packages\pymongo\synchronous\mongo_client.py:2014, in MongoClient._retry_internal(self, func, session, bulk, operation, is_read, address, read_pref, retryable, operation_id)
#    1977 @_csot.apply
#    1978 def _retry_internal(
#    1979     self,
#    (...)
#    1988     operation_id: Optional[int] = None,
#    1989 ) -> T:
#    1990     """Internal retryable helper for all client transactions.
#    1991
#    1992     :param func: Callback function we want to retry
#    (...)
#    2001     :return: Output of the calling func()
#    2002     """
#    2003     return _ClientConnectionRetryable(
#    2004         mongo_client=self,
#    2005         func=func,
#    2006         bulk=bulk,
#    2007         operation=operation,
#    2008         is_read=is_read,
#    2009         session=session,
#    2010         read_pref=read_pref,
#    2011         address=address,
#    2012         retryable=retryable,
#    2013         operation_id=operation_id,
# -> 2014     ).run()
#
# File c:\Users\SENQ\anaconda3\Lib\site-packages\pymongo\synchronous\mongo_client.py:2763, in _ClientConnectionRetryable.run(self)
#    2761 self._check_last_error(check_csot=True)
#    2762 try:
# -> 2763     return self._read() if self._is_read else self._write()
#    2764 except ServerSelectionTimeoutError:
#    2765     # The application may think the write was never attempted
#    2766     # if we raise ServerSelectionTimeoutError on the retry
#    2767     # attempt. Raise the original exception instead.
#    2768     self._check_last_error()
#
# File c:\Users\SENQ\anaconda3\Lib\site-packages\pymongo\synchronous\mongo_client.py:2873, in _ClientConnectionRetryable._write(self)
#    2871 max_wire_version = 0
#    2872 is_mongos = False
# -> 2873 self._server = self._get_server()
#    2874 with self._client._checkout(self._server, self._session) as conn:
#    2875     max_wire_version = conn.max_wire_version
#
# File c:\Users\SENQ\anaconda3\Lib\site-packages\pymongo\synchronous\mongo_client.py:2856, in _ClientConnectionRetryable._get_server(self)
#    2851 def _get_server(self) -> Server:
#    2852     """Retrieves a server object based on provided object context
#    2853
#    2854     :return: Abstraction to connect to server
#    2855     """
# -> 2856     return self._client._select_server(
#    2857         self._server_selector,
#    2858         self._session,
#    2859         self._operation,
#    2860         address=self._address,
#    2861         deprioritized_servers=self._deprioritized_servers,
#    2862         operation_id=self._operation_id,
#    2863     )
#
# File c:\Users\SENQ\anaconda3\Lib\site-packages\pymongo\synchronous\mongo_client.py:1833, in MongoClient._select_server(self, server_selector, session, operation, address, deprioritized_servers, operation_id)
#    1831             raise AutoReconnect("server %s:%s no longer available" % address)  # noqa: UP031
#    1832     else:
# -> 1833         server = topology.select_server(
#    1834             server_selector,
#    1835             operation,
#    1836             deprioritized_servers=deprioritized_servers,
#    1837             operation_id=operation_id,
#    1838         )
#    1839     return server
#    1840 except PyMongoError as exc:
#    1841     # Server selection errors in a transaction are transient.
#
# File c:\Users\SENQ\anaconda3\Lib\site-packages\pymongo\synchronous\topology.py:428, in Topology.select_server(self, selector, operation, server_selection_timeout, address, deprioritized_servers, operation_id)
#     418 def select_server(
#     419     self,
#     420     selector: Callable[[Selection], Selection],
#    (...)
#     425     operation_id: Optional[int] = None,
#     426 ) -> Server:
#     427     """Like select_servers, but choose a random server if several match."""
# --> 428     server = self._select_server(
#     429         selector,
#     430         operation,
#     431         server_selection_timeout,
#     432         address,
#     433         deprioritized_servers,
#     434         operation_id=operation_id,
#     435     )
#     436     if _csot.get_timeout():
#     437         _csot.set_rtt(server.description.min_round_trip_time)
#
# File c:\Users\SENQ\anaconda3\Lib\site-packages\pymongo\synchronous\topology.py:402, in Topology._select_server(self, selector, operation, server_selection_timeout, address, deprioritized_servers, operation_id)
#     393 def _select_server(
#     394     self,
#     395     selector: Callable[[Selection], Selection],
#    (...)
#     400     operation_id: Optional[int] = None,
#     401 ) -> Server:
# --> 402     servers = self.select_servers(
#     403         selector,
#     404         operation,
#     405         server_selection_timeout,
#     406         address,
#     407         operation_id,
#     408         deprioritized_servers,
#     409     )
#     410     if len(servers) == 1:
#     411         return servers[0]
#
# File c:\Users\SENQ\anaconda3\Lib\site-packages\pymongo\synchronous\topology.py:298, in Topology.select_servers(self, selector, operation, server_selection_timeout, address, operation_id, deprioritized_servers)
#     295     self.cleanup_monitors()
#     297 with self._lock:
# --> 298     server_descriptions = self._select_servers_loop(
#     299         selector,
#     300         server_timeout,
#     301         operation,
#     302         operation_id,
#     303         address,
#     304         deprioritized_servers=deprioritized_servers,
#     305     )
#     307     return [
#     308         cast(Server, self.get_server_by_address(sd.address)) for sd in server_descriptions
#     309     ]
#
# File c:\Users\SENQ\anaconda3\Lib\site-packages\pymongo\synchronous\topology.py:359, in Topology._select_servers_loop(self, selector, timeout, operation, operation_id, address, deprioritized_servers)
#     348     if _SERVER_SELECTION_LOGGER.isEnabledFor(logging.DEBUG):
#     349         _debug_log(
#     350             _SERVER_SELECTION_LOGGER,
#     351             message=_ServerSelectionStatusMessage.FAILED,
#    (...)
#     357             failure=self._error_message(selector),
#     358         )
# --> 359     raise ServerSelectionTimeoutError(
#     360         f"{self._error_message(selector)}, Timeout: {timeout}s, Topology Description: {self.description!r}"
#     361     )
#     363 if not logged_waiting:
#     364     _debug_log(
#     365         _SERVER_SELECTION_LOGGER,
#     366         message=_ServerSelectionStatusMessage.WAITING,
#    (...)
#     372         remainingTimeMS=int(1000 * (end_time - time.monotonic())),
#     373     )
#
# ServerSelectionTimeoutError: localhost:27017: [WinError 10061] No connection could be made because the target machine actively refused it (configured timeouts: socketTimeoutMS: 20000.0ms, connectTimeoutMS: 20000.0ms), Timeout: 30s, Topology Description: <TopologyDescription id: 69a3fa721c1bfe19ecde17c0, topology_type: Unknown, servers: [<ServerDescription ('localhost', 27017) server_type: Unknown, rtt: None, error=AutoReconnect('localhost:27017: [WinError 10061] No connection could be made because the target machine actively refused it (configured timeouts: socketTimeoutMS: 20000.0ms, connectTimeoutMS: 20000.0ms)')>]>
